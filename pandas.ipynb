# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshikaAsthana/Pandas_python/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pip install opendatasets

# %%
import opendatasets as od

# %%
od.download("https://www.kaggle.com/datasets/coderanand/ipl-data")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: coderanand
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/coderanand/ipl-data
# ...
# 100%|██████████| 1.20M/1.20M [00:00<00:00, 395MB/s]

# %%
display(df['city'].head())
# Out:
# 0    Hyderabad
# 1         Pune
# 2       Rajkot
# 3       Indore
# 4    Bangalore
# Name: city, dtype: object

# %%
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
df.tail() #less 5 vaUES
# Out:
#         id  season           city      date                  team1  \
# 751  11347    2019         Mumbai  05/05/19  Kolkata Knight Riders
# 752  11412    2019        Chennai  07/05/19    Chennai Super Kings
# 753  11413    2019  Visakhapatnam  08/05/19    Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam  10/05/19         Delhi Capitals
# 755  11415    2019      Hyderabad  12/05/19         Mumbai Indians
#
#                    team2          toss_winner toss_decision  result  \
# 751       Mumbai Indians       Mumbai Indians         field  normal
# 752       Mumbai Indians  Chennai Super Kings           bat  normal
# 753       Delhi Capitals       Delhi Capitals         field  normal
# 754  Chennai Super Kings  Chennai Super Kings         field  normal
# 755  Chennai Super Kings       Mumbai Indians           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 751           0       Mumbai Indians            0               9
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
df.isnull().sum() #less null values we can fill it if more we can drop it
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
df.sample() #random row
# Out:
#       id  season        city        date            team1             team2  \
# 292  293    2011  Dharamsala  2011-05-15  Kings XI Punjab  Delhi Daredevils
#
#           toss_winner toss_decision  result  dl_applied           winner  \
# 292  Delhi Daredevils         field  normal           0  Kings XI Punjab
#
#      win_by_runs  win_by_wickets player_of_match  \
# 292           29               0       PP Chawla
#
#                                             venue    umpire1     umpire2  \
# 292  Himachal Pradesh Cricket Association Stadium  Asad Rauf  SL Shastri
#
#     umpire3
# 292     NaN

# %%
df.isnull().sum()/len(df)*100 #null values in percentage
# Out:
# id                  0.000000
# season              0.000000
# city                0.925926
# date                0.000000
# team1               0.000000
# team2               0.000000
# toss_winner         0.000000
# toss_decision       0.000000
# result              0.000000
# dl_applied          0.000000
# winner              0.529101
# win_by_runs         0.000000
# win_by_wickets      0.000000
# player_of_match     0.529101
# venue               0.000000
# umpire1             0.264550
# umpire2             0.264550
# umpire3            84.259259
# dtype: float64

# %%
df.isnull().mean(axis=1) * 100
# Out:
# 0       5.555556
# 1       5.555556
# 2       5.555556
# 3       5.555556
# 4      16.666667
#          ...
# 751     0.000000
# 752     0.000000
# 753    16.666667
# 754     0.000000
# 755     0.000000
# Length: 756, dtype: float64

# %%
len(df.columns)
# Out:
# 18

# %%
df["city"]
# Out:
# 0          Hyderabad
# 1               Pune
# 2             Rajkot
# 3             Indore
# 4          Bangalore
#            ...
# 751           Mumbai
# 752          Chennai
# 753    Visakhapatnam
# 754    Visakhapatnam
# 755        Hyderabad
# Name: city, Length: 756, dtype: object

# %%
df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
# df=df.drop('umpire3', axis=1)

# %%
df['city'].value_counts().isnull()
# Out:
# city
# Mumbai            False
# Kolkata           False
# Delhi             False
# Bangalore         False
# Hyderabad         False
# Chennai           False
# Jaipur            False
# Chandigarh        False
# Pune              False
# Durban            False
# Bengaluru         False
# Visakhapatnam     False
# Centurion         False
# Ahmedabad         False
# Mohali            False
# Rajkot            False
# Dharamsala        False
# Indore            False
# Johannesburg      False
# Port Elizabeth    False
# Abu Dhabi         False
# Cape Town         False
# Ranchi            False
# Cuttack           False
# Sharjah           False
# Raipur            False
# Kochi             False
# Kanpur            False
# Kimberley         False
# Nagpur            False
# East London       False
# Bloemfontein      False
# Name: count, dtype: bool

# %%
df[df['city'].isnull()]
# Out:
#       id  season city        date                        team1  \
# 461  462    2014  NaN  2014-04-19               Mumbai Indians
# 462  463    2014  NaN  2014-04-19        Kolkata Knight Riders
# 466  467    2014  NaN  2014-04-23          Chennai Super Kings
# 468  469    2014  NaN  2014-04-25          Sunrisers Hyderabad
# 469  470    2014  NaN  2014-04-25               Mumbai Indians
# 474  475    2014  NaN  2014-04-28  Royal Challengers Bangalore
# 476  477    2014  NaN  2014-04-30          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 461  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 462             Delhi Daredevils        Kolkata Knight Riders           bat
# 466             Rajasthan Royals             Rajasthan Royals         field
# 468             Delhi Daredevils          Sunrisers Hyderabad           bat
# 469          Chennai Super Kings               Mumbai Indians           bat
# ...

# %%
display(df.head()) # Display the head of the DataFrame
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
import numpy as np

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-41-1431866573.py in <cell line: 0>()
# ----> 1 pd.read_csv("/content/dummydata.csv")
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
# ...

# %%
dummy_df = {'name': ['himanshu', 'anshika', 'monkey', 'giraffe'],
        'id': [1, 4, 8, 9],
        'marks': np.random.randint(50, 100, size=4), # Generating random marks between 50 and 100
        'rank': ['pg', 'ug', 'ug', 'pg']} # Assigning ranks

# %%
# Assuming 'data' dictionary is already defined in a previous cell
data = pd.DataFrame(dummy_df)

# %%
data
# Out:
#        name  id  marks rank
# 0  himanshu   1     83   pg
# 1   anshika   4     67   ug
# 2    monkey   8     65   ug
# 3   giraffe   9     93   pg

# %%
df.dropna() #drop entire row that contain any null values
# Out:
#         id  season           city        date                   team1  \
# 0        1    2017      Hyderabad  2017-04-05     Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06          Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07           Gujarat Lions
# 3        4    2017         Indore  2017-04-08  Rising Pune Supergiant
# 5        6    2017      Hyderabad  2017-04-09           Gujarat Lions
# ..     ...     ...            ...         ...                     ...
# 750  11346    2019         Mohali    05/05/19     Chennai Super Kings
# 751  11347    2019         Mumbai    05/05/19   Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19     Chennai Super Kings
# 754  11414    2019  Visakhapatnam    10/05/19          Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19          Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# id                 0
# season             0
# city               0
# date               0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# result             0
# dl_applied         0
# winner             0
# win_by_runs        0
# win_by_wickets     0
# player_of_match    0
# venue              0
# umpire1            0
# umpire2            0
# dtype: int64

# %%
df["winner"]
# Out:
# 0         Sunrisers Hyderabad
# 1      Rising Pune Supergiant
# 2       Kolkata Knight Riders
# 3             Kings XI Punjab
# 5         Sunrisers Hyderabad
#                 ...
# 750           Kings XI Punjab
# 751            Mumbai Indians
# 752            Mumbai Indians
# 754       Chennai Super Kings
# 755            Mumbai Indians
# Name: winner, Length: 743, dtype: object

# %%
df["winner"].value_counts()
# Out:
# winner
# Mumbai Indians                 109
# Chennai Super Kings             98
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     82
# Kings XI Punjab                 81
# Rajasthan Royals                75
# Delhi Daredevils                66
# Sunrisers Hyderabad             56
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Delhi Capitals                   9
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: count, dtype: int64

# %%
df["winner"].replace("Rising Pune Supergiants","Rising Pune Supergiant")
# Out:
# 0         Sunrisers Hyderabad
# 1      Rising Pune Supergiant
# 2       Kolkata Knight Riders
# 3             Kings XI Punjab
# 5         Sunrisers Hyderabad
#                 ...
# 750           Kings XI Punjab
# 751            Mumbai Indians
# 752            Mumbai Indians
# 754       Chennai Super Kings
# 755            Mumbai Indians
# Name: winner, Length: 743, dtype: object

# %%
df["winner"].value_counts()
# Out:
# winner
# Mumbai Indians                 109
# Chennai Super Kings             98
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     82
# Kings XI Punjab                 81
# Rajasthan Royals                75
# Delhi Daredevils                66
# Sunrisers Hyderabad             56
# Deccan Chargers                 29
# Rising Pune Supergiant          15
# Gujarat Lions                   13
# Pune Warriors                   12
# Delhi Capitals                   9
# Kochi Tuskers Kerala             6
# Name: count, dtype: int64

# %%
df["winner"].replace("Delhi Daredevils","Delhi Capitals")
# Out:
# 0         Sunrisers Hyderabad
# 1      Rising Pune Supergiant
# 2       Kolkata Knight Riders
# 3             Kings XI Punjab
# 5         Sunrisers Hyderabad
#                 ...
# 750           Kings XI Punjab
# 751            Mumbai Indians
# 752            Mumbai Indians
# 754       Chennai Super Kings
# 755            Mumbai Indians
# Name: winner, Length: 743, dtype: object

# %%
df["winner"].value_counts()
# Out:
# winner
# Mumbai Indians                 109
# Chennai Super Kings             98
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     82
# Kings XI Punjab                 81
# Rajasthan Royals                75
# Delhi Daredevils                66
# Sunrisers Hyderabad             56
# Deccan Chargers                 29
# Rising Pune Supergiant          15
# Gujarat Lions                   13
# Pune Warriors                   12
# Delhi Capitals                   9
# Kochi Tuskers Kerala             6
# Name: count, dtype: int64

# %%
mumbai_city=df[df["city"]=="Mumbai"]

# %%
mumbai_city
# Out:
#         id  season    city        date                        team1  \
# 6        7    2017  Mumbai  2017-04-09        Kolkata Knight Riders
# 9       10    2017  Mumbai  2017-04-12          Sunrisers Hyderabad
# 15      16    2017  Mumbai  2017-04-16                Gujarat Lions
# 23      24    2017  Mumbai  2017-04-22               Mumbai Indians
# 27      28    2017  Mumbai  2017-04-24       Rising Pune Supergiant
# ..     ...     ...     ...         ...                          ...
# 719  11315    2019  Mumbai    10/04/19              Kings XI Punjab
# 722  11318    2019  Mumbai    13/04/19               Mumbai Indians
# 726  11322    2019  Mumbai    15/04/19  Royal Challengers Bangalore
# 746  11342    2019  Mumbai    02/05/19               Mumbai Indians
# 751  11347    2019  Mumbai    05/05/19        Kolkata Knight Riders
#
#                    team2       toss_winner toss_decision  result  dl_applied  \
# ...

# %%
#win probablity of team if match with mumbai

# %%
mumbai_matches = df[df['city'] == 'Mumbai']

# %%
mumbai_win_pb = mumbai_matches['winner'].value_counts() / mumbai_matches['team1'].value_counts().add(mumbai_matches['team2'].value_counts())

# %%
display(mumbai_win_pb.sort_values())
# Out:
# Kolkata Knight Riders          0.230769
# Delhi Daredevils               0.250000
# Sunrisers Hyderabad            0.250000
# Pune Warriors                  0.300000
# Deccan Chargers                0.333333
# Royal Challengers Bangalore    0.384615
# Kings XI Punjab                0.384615
# Kochi Tuskers Kerala           0.500000
# Gujarat Lions                  0.500000
# Rajasthan Royals               0.500000
# Chennai Super Kings            0.550000
# Mumbai Indians                 0.646341
# Delhi Capitals                      NaN
# Rising Pune Supergiant              NaN
# Rising Pune Supergiants             NaN
# Name: count, dtype: float64

# %%
display(mumbai_win_pb.sort_values(ascending=False))
# Out:
# Mumbai Indians                 0.646341
# Chennai Super Kings            0.550000
# Kochi Tuskers Kerala           0.500000
# Gujarat Lions                  0.500000
# Rajasthan Royals               0.500000
# Kings XI Punjab                0.384615
# Royal Challengers Bangalore    0.384615
# Deccan Chargers                0.333333
# Pune Warriors                  0.300000
# Delhi Daredevils               0.250000
# Sunrisers Hyderabad            0.250000
# Kolkata Knight Riders          0.230769
# Delhi Capitals                      NaN
# Rising Pune Supergiant              NaN
# Rising Pune Supergiants             NaN
# Name: count, dtype: float64
